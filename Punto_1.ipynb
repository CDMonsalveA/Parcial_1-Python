# %%
# Setup: python3
# %pip install ipykernel
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install openpyxl
# %pip install xlrd
# %pip install pulp
# Out:
# Requirement already satisfied: ipykernel in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (6.22.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: comm>=0.1.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (8.12.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (8.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: packaging in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (23.0)
# Requirement already satisfied: psutil in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (6.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: backcall in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.15.0)
# Requirement already satisfied: stack-data in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: colorama in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: pandas in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (1.24.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (3.7.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: openpyxl in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (3.1.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: et-xmlfile in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: xlrd in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pulp in c:\users\home\onedrive\1_ universidad\logística ii\parcial_1-python\.venv\lib\site-packages (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pulp import *
import openpyxl
import xlrd

# Read the data from the excel file data\punto 1.xlsx
Table_1 = pd.read_excel('data\punto 1.xlsx', sheet_name='Table_1')
Table_2 = pd.read_excel('data\punto 1.xlsx', sheet_name='Table_2')
# Print the data
display(Table_1, Table_2)
# Out:
#   Producto  Demanda Mensual (cajas)   Cp  Cm ($/(caja*mes))  Cajas/tarima
# 0        A                     3000  100                 40             6  \
# 1        B                     4000  100                 45             2
# 2        C                     3500  100                 35             4
#
#    Cajas/viaje Despacho
# 0                   3.0
# 1                   1.5
# 2                   2.5
#     Sección  Distancia a Recepción (m)  Distancia a Despacho (m)
# 0         1                        137                       112
# 1         2                        121                        96
# 2         3                        105                        80
# 3         4                        106                        48
# 4         5                        121                        32
# 5         6                        107                       110
# 6         7                         91                        94
# 7         8                         75                        78
# 8         9                         76                        46
# 9        10                         92                        30
# 10       11                         77                       145
# 11       12                         61                       129
# 12       13                         45                       113
# 13       14                         46                        81
# 14       15                         62                        65

# %%
# for table 1, add column # Tarimas = Demanda Mensual (cajas)/Cajas/tarima
Table_1['# Tarimas'] = Table_1['Demanda Mensual (cajas)']/Table_1['Cajas/tarima']
# for table 1, add column Tarimas/viaje = 2
Table_1['Tarimas/viaje'] = 2
# for table 1, add column # Viajes Recepción = # Tarimas/Tarimas/viaje
Table_1['# Viajes Recepción'] = Table_1['# Tarimas']/Table_1['Tarimas/viaje']
# for table 1, add column # Viajes Despacho = Demanda Mensual (cajas)/Cajas/viaje Despacho
Table_1['# Viajes Despacho'] = Table_1['Demanda Mensual (cajas)']/Table_1['Cajas/viaje Despacho']
# Get Relation IN/OUT
Table_1['Relation IN/OUT'] = Table_1['# Viajes Recepción']/Table_1['# Viajes Despacho']
# for table 1, add column Q = square_root(2*Cp*Demanda Mensual (cajas) / Cm ($/(caja*mes)))
Table_1['Q'] = np.sqrt(2*Table_1['Cp']*Table_1['Demanda Mensual (cajas)']/Table_1['Cm ($/(caja*mes))'])
# for table 1. add column S = round up Q/Cajas/tarima
Table_1['S'] = np.ceil(Table_1['Q']/Table_1['Cajas/tarima'])
# for table 1, add column # Tarimas/Seccion = 10
Table_1['# Tarimas/Seccion'] = 10
# for table 1, add column # Secciones = S/# Tarimas/Seccion
Table_1['# Secciones'] =  np.ceil(+Table_1['S']/Table_1['# Tarimas/Seccion'])
# Ask how many sections are there
#Sections = int(input('How many sections are there? '))
Sections = 15
# if sum(# Secciones) <= Sections, tell, the number of sections is enough
if Table_1['# Secciones'].sum() <= Sections:
    print('The number of sections is enough')
# if sum(# Secciones) > Sections, tell, the number of sections is not enough
else:
    print('The number of sections is not enough')
# ask for the cost of Recepcion
#Cost_Recepcion = int(input('What is the cost of Recepcion? '))
Cost_Recepcion = 15
# ask for the cost per meter of Recepcion
#Cost_Recepcion_m = int(input('What is the cost per meter of Recepcion? '))
Cost_Recepcion_m = 2.0
# ask for the cost of Despacho
#Cost_Despacho = int(input('What is the cost of Despacho? '))
Cost_Despacho = 40
# ask for the cost per meter of Despacho
#Cost_Despacho_m = int(input('What is the cost per meter of Despacho? '))
Cost_Despacho_m = 0.5
# Out:
# The number of sections is enough

# %%
# Solution through PuLP
# indexes:
# i: products
# j: sections
# Variables:
# x[i,j]: 1 if product i is in section j, 0 otherwise
# Parameters:
# vr[i]: number of trips for receiving product i
# vd[i]: number of trips for delivering product i
# dr[j]: distance for receiving in section j
# dd[j]: distance for delivering in section j
# cr_m: cost per meter for receiving (travel must be done twice)
# cd_m: cost per meter for delivering (travel must be done twice)
# cr: cost per trip for receiving
# cd: cost per trip for delivering
# c[i,j]: cost of product i in section j
# s[i]: number of sections needed for product i
# M: big number
# Objective:
# min sum(i,j) c[i,j]*x[i,j]
# Constraints:
# sum(j) x[i,j] = b[i] for all i
# sum(i) x[i,j] <= 1 for all j
# x[i,j] in {0,1} for all i,j

# Create the 'prob' variable to contain the problem data
prob = LpProblem("The Warehouse Problem", LpMinimize)
# Create the decision variables
x = LpVariable.dicts("x", ((i, j) for i in Table_1['Producto'] for j in range(Sections)), cat='Binary')
# Get the Parameters
# Out:
# c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pulp\pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Distancia a Recepción (m)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 23
#      21 x = LpVariable.dicts("x", ((i, j) for i in Table_1['Producto'] for j in range(Sections)), cat='Binary')
#      22 # get the cost of product i in section j c[i,j] = 2*(# Viajes Recepción*Distancia a Recepción (m)*Cost_Recepcion_m+# Viajes Despacho*Distancia a Despacho (m)*Cost_Despacho_m)/(s[i])+# Viajes Despacho*Cost_Despacho+# Viajes Recepción*Cost_Recepcion
# ---> 23 c = {(i, j): 2*(Table_1.loc[Table_1['Producto'] == i, '# Viajes Recepción'].values[0]*Table_1.loc[Table_1['Producto'] == i, 'Distancia a Recepción (m)'].values[0]*Cost_Recepcion_m+Table_1.loc[Table_1['Producto'] == i, '# Viajes Despacho'].values[0]*Table_1.loc[Table_1['Producto'] == i, 'Distancia a Despacho (m)'].values[0]*Cost_Despacho_m)/(Table_1.loc[Table_1['Producto'] == i, '# Secciones'].values[0])+Table_1.loc[Table_1['Producto'] == i, '# Viajes Despacho'].values[0]*Cost_Despacho+Table_1.loc[Table_1['Producto'] == i, '# Viajes Recepción'].values[0]*Cost_Recepcion for j in range(Sections) for i in Table_1['Producto']}
#
# Cell In[5], line 23, in <dictcomp>(.0)
#      21 x = LpVariable.dicts("x", ((i, j) for i in Table_1['Producto'] for j in range(Sections)), cat='Binary')
#      22 # get the cost of product i in section j c[i,j] = 2*(# Viajes Recepción*Distancia a Recepción (m)*Cost_Recepcion_m+# Viajes Despacho*Distancia a Despacho (m)*Cost_Despacho_m)/(s[i])+# Viajes Despacho*Cost_Despacho+# Viajes Recepción*Cost_Recepcion
# ---> 23 c = {(i, j): 2*(Table_1.loc[Table_1['Producto'] == i, '# Viajes Recepción'].values[0]*Table_1.loc[Table_1['Producto'] == i, 'Distancia a Recepción (m)'].values[0]*Cost_Recepcion_m+Table_1.loc[Table_1['Producto'] == i, '# Viajes Despacho'].values[0]*Table_1.loc[Table_1['Producto'] == i, 'Distancia a Despacho (m)'].values[0]*Cost_Despacho_m)/(Table_1.loc[Table_1['Producto'] == i, '# Secciones'].values[0])+Table_1.loc[Table_1['Producto'] == i, '# Viajes Despacho'].values[0]*Cost_Despacho+Table_1.loc[Table_1['Producto'] == i, '# Viajes Recepción'].values[0]*Cost_Recepcion for j in range(Sections) for i in Table_1['Producto']}
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File c:\Users\Home\OneDrive\1_ Universidad\Logística II\Parcial_1-Python\.venv\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Distancia a Recepción (m)'
